# %% [markdown]
# **LIFE CYCLE OF DATA SCIENCE**

# %% [markdown]
#                                   Data read
#                                       |
#                                   Data cleaning
#                                       |
#                                   Data Analysis
#                                       |
#                                   Feature engineering
#                                       |
#                                   Feature selection
#                                       |
#                                   Model development
#                                       |
#                                   Model evaluation
#                                       |
#                                   Model tuning
#                                       |
#                                   Model deployment

# %% [markdown]
# **Feature Engineering**
#
# - so far we have performed feature analysis
#
#     - Data frame quick checks
#
#     - Categorical column analysis
#
#     - Bar charts, Pie charts
#
#     - Numerical column analysis
#
#     - Histogram, box plot, outliers
#
#     - Bi-multi variate analysis
#
#     - correlation etc
#
# - Now we need to learn Feature Engineering
#
#     - we will create a new columns for better ML models
#
#     - we will perform the **Encoding**, which is convert categorical to numerical data
#
#     - we will do data **transformations**
#
#     - we will perform **scalling: Standardization and Normalization**
#
#     - we will perform the **missing value analysis**
#
# - Simply feature engineering means our data will be modified

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

visa_df=pd.read_csv(r"C:\Users\HP\Documents\NareshIT\Data_Files\Visadataset.csv")
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %%
import pandas as pd

# %% [markdown]
# **Case_status**

# %%
# first check how many unique lables are there in case_status
visa_df['case_status']
visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
# crate a dictionary
d ={'Certified':0,'Denied':1}
d
# Out:
# {'Certified': 0, 'Denied': 1}

# %%
# map the above the dictionary with original column
visa_df['case_status']=visa_df['case_status'].map(d)  # dictionay d

# %%
visa_df['case_status']
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 25475    0
# 25476    0
# 25477    0
# 25478    0
# 25479    0
# Name: case_status, Length: 25480, dtype: int64

# %%
labels=sorted(visa_df['education_of_employee'].unique())
d={j:i for i,j in enumerate(labels)}
visa_df['education_of_employee'].map(d)
# Out:
# 0        2
# 1        3
# 2        0
# 3        0
# 4        3
#         ..
# 25475    0
# 25476    2
# 25477    3
# 25478    3
# 25479    0
# Name: education_of_employee, Length: 25480, dtype: int64

# %%
d
# Out:
# {"Bachelor's": 0, 'Doctorate': 1, 'High School': 2, "Master's": 3}

# %% [markdown]
# - there are two rn==encodings
#
#     - LabelEncoder
#
#     - OrdinalEncoder

# %% [markdown]
# **Tyoes of encoders**

# %% [markdown]
# Education     LabelEncoder       OrdinalEncoder
# ====================================================
# HighSchool      1                   0
#
# Bachelor        0                   1
#
# Masters         2                   2
#
# PH.D            3                   3
#
#
# 1   0   2   3 ===> ML model sees this: 3>2>1>0
# which indicates: PH.D>Master>HighSchool>Bachelor

# %%
# read the data
visa_df=pd.read_csv(r"C:\Users\HP\Documents\NareshIT\Data_Files\Visadataset.csv")

# %%
import sklearn
dir(sklearn)
# Out:
# ['calibration',
#  'clone',
#  'cluster',
#  'compose',
#  'config_context',
#  'covariance',
#  'cross_decomposition',
#  'datasets',
#  'decomposition',
#  'discriminant_analysis',
#  'dummy',
#  'ensemble',
#  'exceptions',
#  'experimental',
#  'externals',
#  'feature_extraction',
#  'feature_selection',
#  'frozen',
#  'gaussian_process',
#  'get_config',
#  'impute',
#  'inspection',
#  'isotonic',
#  'kernel_approximation',
#  'kernel_ridge',
#  'linear_model',
#  'manifold',
#  'metrics',
#  'mixture',
#  'model_selection',
#  'multiclass',
#  'multioutput',
#  'naive_bayes',
#  'neighbors',
#  'neural_network',
#  'pipeline',
#  'preprocessing',
#  'random_projection',
#  'semi_supervised',
#  'set_config',
#  'show_versions',
#  'svm',
#  'tree']

# %%
- sklearn: **Package**

    - preprocessing: **module**

        - LabelEncoder: **class**

             - fit_transform: **method**

import sklearn
sklearn.preprocessing

from sklearn import preprocessing
dir(preproceesing): LabelEncoder
preprocessing.LableEncoder

from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
le.fit_transform()


# Read the class
# save the class
# apply the fit transform

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
le.fit_transform

from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()
oe.fit_transform()

# %% [markdown]
# **fit transform**
#
# - fit: created a dictionary(find something)
#
# - transform: using above finding we are modify the data
#
# from sklearn.module import class
#
# va=class()
#
# va.fit or va.fit_transform

# %% [markdown]
#  interview que what is fit and what is transform

# %%
# 11-8-26

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **LabelEncoder**

# %%
from sklearn.preprocessing import LabelEncoder
Le = LabelEncoder()
visa_df['casw_status']=le.fit_transform(visa_df['case_status'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from sklearn.preprocessing import LabelEncoder
#       2 Le = LabelEncoder()
# ----> 3 visa_df['casw_status']=le.fit_transform(visa_df['case_status'])
#
# NameError: name 'le' is not defined

# %%
# Read the data again
visa_df=pd.read_csv(r"C:\Users\HP\Documents\NareshIT\Data_Files\Visadataset.csv")

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in cat[1:]:    # Dont consider case id
    visa_df[i]=le.fit_transform(visa_df[i])

# %%
visa_df
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          1                      2                   0
# 1         EZYV02          1                      3                   1
# 2         EZYV03          1                      0                   0
# 3         EZYV04          1                      0                   0
# 4         EZYV05          0                      3                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          1                      0                   1
# 25476  EZYV25477          1                      2                   1
# 25477  EZYV25478          1                      3                   1
# 25478  EZYV25479          1                      3                   1
# 25479  EZYV25480          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
# interview que what is ordinal_column vs label_column when to use ordinal column when to use
# label column most imp for interview que

# %%
# Read the data again
visa_df=pd.read_csv(r"C:\Users\HP\Documents\NareshIT\Data_Files\Visadataset.csv")

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()
for i in cat[1:]:    # Dont consider case id
    visa_df[i]=oe.fit_transform(visa_df[[i]])

# %%
visa_df
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01        1.0                    2.0                 0.0
# 1         EZYV02        1.0                    3.0                 1.0
# 2         EZYV03        1.0                    0.0                 0.0
# 3         EZYV04        1.0                    0.0                 0.0
# 4         EZYV05        0.0                    3.0                 1.0
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476        1.0                    0.0                 1.0
# 25476  EZYV25477        1.0                    2.0                 1.0
# 25477  EZYV25478        1.0                    3.0                 1.0
# 25478  EZYV25479        1.0                    3.0                 1.0
# 25479  EZYV25480        1.0                    0.0                 1.0
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
# Read the data again
visa_df=pd.read_csv(r"C:\Users\HP\Documents\NareshIT\Data_Files\Visadataset.csv")

# %% [markdown]
# **pd.get_dummies**

# %% [markdown]
# - get dummies is a way to represent the categorical columns to numerical
#
# - first it will check what are the labels in a column
#
# - for example case status has two labels
#
#     - Denied and Certified
#
# - So it will create two new columns based on labels
#
#     - col1: case_status_Denied
#     - col2: case_status_Certified
#
#
#   case_Status|  case_status_Denied| Case_status_Certified
#      -       |           -         |          -
#   Denied     |           1         |          0
#   Certified  |           0         |          1
#   Certified  |           0         |          1
#
#
# **It is also called as One Hot Encoder**
#
# - It makes new columns are independent each other
#
# - some of ML algorithms expect that columns should be independent each other

# %%
pd.get_dummies(visa_df['case_status'],
               dtype=int)
# Out:
#        Certified  Denied
# 0              0       1
# 1              1       0
# 2              0       1
# 3              0       1
# 4              1       0
# ...          ...     ...
# 25475          1       0
# 25476          1       0
# 25477          1       0
# 25478          1       0
# 25479          1       0
#
# [25480 rows x 2 columns]
