# %%
# 3/8/2026

# %% [markdown]
# **Step-1: Import packages and read the data**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

visa_df=pd.read_csv(r"C:\Users\HP\Documents\NareshIT\Data_Files\Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **Step-2: Seperate Cat and Num columns**

# %%
cat=visa_df.select_dtypes(include='object').columns.tolist()
num=visa_df.select_dtypes(exclude='object').columns.tolist()

# %% [markdown]
# - Frequency table
#
# - Relative frequency table
#
# - Bar chart
#
# - Pie chart

# %% [markdown]
# **Step-3: Frequency table**

# %%
cat
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
num
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
visa_df['continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
visa_df['continent'].nunique()
# Out:
# 6

# %% [markdown]
# - There are 25480 applicants from 6 continents
#
# - Number of applicants from each continent: **Frequency table**

# %%
# Number of applicants from 'Asia'
visa_df  # Df
visa_df['continent']  # one column
con=visa_df['continent']=='Asia'  # one class
con    #  # 1= True , # 0= False
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 25475     True
# 25476     True
# 25477     True
# 25478     True
# 25479     True
# Name: continent, Length: 25480, dtype: bool

# %%
np.sum(con)   # 1= True , # 0= False
# Out:
# np.int64(16861)

# %%
# Number of applicants from 'Asia'
visa_df  # Df
visa_df['continent']  # one column
con=visa_df['continent']=='Asia'  # one class
np.sum(con)   # sum   1+1+1+1+0+1
visa_df[con]  # extraction
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 5         EZYV06      Asia              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# hence 16861 applicants from asia

# %%
# con=visa_df['continent']=='Asia' # one class
# np.sum(con)

# con=visa_df['continent']=='Africa' # one class
# np.sum(con)

# con=visa_df

# %%
cont_class=visa_df['continent'].unique()
freq=[]
for i in cont_class:
    con=visa_df['continent']==i  # one class
    freq.append(np.sum(con))
    
pd.DataFrame(zip(cont_class,freq),
             columns=['Class','Frequency'])
# Out:
#            Class  Frequency
# 0           Asia      16861
# 1         Africa        551
# 2  North America       3292
# 3         Europe       3732
# 4  South America        852
# 5        Oceania        192

# %% [markdown]
# **Value_counts**

# %%
visa_df['continent'].value_counts() # it is a series
                                    # DataFrame means two columns need
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
type(visa_df['continent'].value_counts())
# Out:
# pandas.core.series.Series

# %%
keys=visa_df['continent'].value_counts().keys()
values=visa_df['continent'].value_counts().values
pd.DataFrame(zip(keys,values),columns=['Class','Frequency'])
# Out:
#            Class  Frequency
# 0           Asia      16861
# 1         Europe       3732
# 2  North America       3292
# 3  South America        852
# 4         Africa        551
# 5        Oceania        192

# %%
list(visa_df.groupby(by='continent'))
# Out:
# [('Africa',
#            case_id continent education_of_employee has_job_experience  \
#   4         EZYV05    Africa              Master's                  Y
#   18        EZYV19    Africa              Master's                  Y
#   74        EZYV75    Africa              Master's                  Y
#   194      EZYV195    Africa              Master's                  Y
#   242      EZYV243    Africa            Bachelor's                  N
#   ...          ...       ...                   ...                ...
#   25385  EZYV25386    Africa             Doctorate                  Y
#   25408  EZYV25409    Africa              Master's                  Y
#   25443  EZYV25444    Africa            Bachelor's                  N
#   25446  EZYV25447    Africa              Master's                  N
#   25474  EZYV25475    Africa             Doctorate                  N
#
#         requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
visa_df.groupby(by='continent').count()['case_id']
# Out:
# continent
# Africa             551
# Asia             16861
# Europe            3732
# North America     3292
# Oceania            192
# South America      852
# Name: case_id, dtype: int64

# %%
# except case_id do for all other columns

# %%
visa_df.groupby(by='continent').count()['education_of_employee']
# Out:
# continent
# Africa             551
# Asia             16861
# Europe            3732
# North America     3292
# Oceania            192
# South America      852
# Name: education_of_employee, dtype: int64

# %% [markdown]
# **Bar Chart**

# %% [markdown]
# - X-axis: class names(keys)
#
# - y-axis: Frequency(values)

# %%
keys=visa_df['continent'].value_counts().keys()
values=visa_df['continent'].value_counts().values

# %%
plt.figure(figsize=(10,4))
plt.bar(keys,values)
plt.xlabel('continents')
plt.ylabel('No of applicants')
plt.title('Bar chart')
plt.show()

# %%
# 4/8/2026

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv(r"C:\Users\HP\Documents\NareshIT\Data_Files\Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df['continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df['continent'].value_counts()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
keys=visa_df['continent'].value_counts().keys()
values=visa_df['continent'].value_counts().values
pd.DataFrame(zip(keys,values),columns=['Class','Frequency'])
# Out:
#            Class  Frequency
# 0           Asia      16861
# 1         Europe       3732
# 2  North America       3292
# 3  South America        852
# 4         Africa        551
# 5        Oceania        192

# %% [markdown]
# **Bar Chart**

# %% [markdown]
# - X-axis: class names(keys)
#
# - y-axis: Frequency(values)

# %%
keys=visa_df['continent'].value_counts().keys()
values=visa_df['continent'].value_counts().values

# %%
plt.figure(figsize=(10,4))
plt.bar(keys,values)
plt.xlabel('continents')
plt.ylabel('No of applicants')
plt.title('Bar chart')
plt.show()

# %%
from matplotlib.colors import CSS4_COLORS
CSS4_COLORS
# Out:
# {'aliceblue': '#F0F8FF',
#  'antiquewhite': '#FAEBD7',
#  'aqua': '#00FFFF',
#  'aquamarine': '#7FFFD4',
#  'azure': '#F0FFFF',
#  'beige': '#F5F5DC',
#  'bisque': '#FFE4C4',
#  'black': '#000000',
#  'blanchedalmond': '#FFEBCD',
#  'blue': '#0000FF',
#  'blueviolet': '#8A2BE2',
#  'brown': '#A52A2A',
#  'burlywood': '#DEB887',
#  'cadetblue': '#5F9EA0',
#  'chartreuse': '#7FFF00',
#  'chocolate': '#D2691E',
#  'coral': '#FF7F50',
#  'cornflowerblue': '#6495ED',
#  'cornsilk': '#FFF8DC',
#  'crimson': '#DC143C',
#  'cyan': '#00FFFF',
#  'darkblue': '#00008B',
#  'darkcyan': '#008B8B',
#  'darkgoldenrod': '#B8860B',
#  'darkgray': '#A9A9A9',
#  'darkgreen': '#006400',
#  'darkgrey': '#A9A9A9',
#  'darkkhaki': '#BDB76B',
#  'darkmagenta': '#8B008B',
#  'darkolivegreen': '#556B2F',
#  'darkorange': '#FF8C00',
#  'darkorchid': '#9932CC',
#  'darkred': '#8B0000',
#  'darksalmon': '#E9967A',
#  'darkseagreen': '#8FBC8F',
#  'darkslateblue': '#483D8B',
#  'darkslategray': '#2F4F4F',
# ...

# %%
colors=['Red', 'Blue', 'Green', 'Yellow', 'Pink', 'Purple']
plt.figure(figsize=(10,4))
plt.bar(keys,
        values,
        color=colors)
plt.xlabel('Continents')
plt.ylabel('No Of applicants')
plt.title('Bar chart')
plt.savefig('Continent_bar.jpg')
plt.show()

# %% [markdown]
# **Pie Chart**
#
# - autopct=%a.bf%%
#
# - first % is the formatting
#
# - a: how much min width
#
# - b: after point how many decimals
#
# - %%: % symbols
#
# - %1.1f%%: 40.2%
#
# - %2.2f%%: 423.23

# %%
keys=visa_df['continent'].value_counts().keys()
values=visa_df['continent'].value_counts().values
#pit.pie(x,labels)
plt.pie(values,
        explode=[0.1 for i in range(6)],
        labels=keys,
        autopct='%1.2f%%',
        radius=0.8,         # By defualt radius=1  
        startangle=40)      # rotation of angles/piechcart
plt.savefig('continent_pie.jpg')
plt.show()

# %% [markdown]
# **Relative Frequency Table**

# %%
visa_df['continent'].value_counts(normalize=True)*100
# Out:
# continent
# Asia             66.173469
# Europe           14.646782
# North America    12.919937
# South America     3.343799
# Africa            2.162480
# Oceania           0.753532
# Name: proportion, dtype: float64

# %% [markdown]
# **Subplots**

# %%
# plt.subplot(2,2,1)
# plt.subplot(2,2,2)
# plt.subplot(2,2,3)
# plt.subplot(2,2,4)

for i in range(1,5):
    plt.subplot(2,2,i)

# %%
keys=visa_df['continent'].value_counts().keys()
values=visa_df['continent'].value_counts().values
plt.bar(keys,values)
plt.show()

# %%
cols=['continent','case_status']

keys1=visa_df['continent'].value_counts().keys()
values1=visa_df['continent'].value_counts().values
plt.subplot(1,2,1)
plt.bar(keys1,values1)

keys2=visa_df['case_status'].value_counts().keys()
values2=visa_df['case_status'].value_counts().values
plt.subplot(1,2,2)
plt.bar(keys2,values2)

    # separate bar chart sathi
# Out:
# <BarContainer object of 2 artists>

# %%
cols=['continent', 'case_status']
plt.figure(figsize=(18,3))
for i in range(len(cols)):
    c=cols[i]
    keys=visa_df[c].value_counts().keys()
    values=visa_df[c].value_counts().values
    plt.subplot(1,2,i+1).bar(keys,values)

# %%
cols=['continent', 'case_status','education_of_employee','has_job_experience','requires_job_training','unit_of_wage','full_time_position','case_status']
plt.figure(figsize=(28,15))
for i in range(len(cols)):
    c=cols[i]
    keys=visa_df[c].value_counts().keys()
    values=visa_df[c].value_counts().values
    plt.subplot(3,3,i+1).bar(keys,values,)

# %% [markdown]
#                         Import the package and read the data
#                                         |
#                         Separate Categorical and Numerical Columns
#                                         |
#                                 Frequency Table
#                                         |
#                                     Bar chart
#                                         |
#                                     Pie chart
